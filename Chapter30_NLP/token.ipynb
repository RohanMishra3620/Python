# %%
import nltk
# nltk.download('punkt')
from nltk.tokenize import word_tokenize ,sent_tokenize

# %%
sent=sent_tokenize("Natural Language Processing (NLP) is a branch of artificial intelligence that enables computers to understand, interpret, and generate human language. It is used in applications such as chatbots, language translation, sentiment analysis, speech recognition, and text summarization. By combining linguistics and machine learning, NLP helps machines communicate with people in a more natural and meaningful way.")
for i, sentence in enumerate(sent, 1):
    print("Sentence", i, ":", sentence)
# Out:
# Sentence 1 : Natural Language Processing (NLP) is a branch of artificial intelligence that enables computers to understand, interpret, and generate human language.
# Sentence 2 : It is used in applications such as chatbots, language translation, sentiment analysis, speech recognition, and text summarization.
# Sentence 3 : By combining linguistics and machine learning, NLP helps machines communicate with people in a more natural and meaningful way.

# %%
word_tokenize("Every day is a new opportunity to learn something, grow, and become a better version of yourself.")
# Out:
# ['Every',
#  'day',
#  'is',
#  'a',
#  'new',
#  'opportunity',
#  'to',
#  'learn',
#  'something',
#  ',',
#  'grow',
#  ',',
#  'and',
#  'become',
#  'a',
#  'better',
#  'version',
#  'of',
#  'yourself',
#  '.']

# %%
from nltk.corpus import stopwords
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\C9IN\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stopwords=stopwords.words("English")
print(len(stopwords))
print(stopwords)
# Out:
# 198
# ...
