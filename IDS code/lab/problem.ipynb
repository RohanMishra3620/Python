# %%
import pandas as pd

a=pd.Series([1,2,3,4,5])
print(a)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
a=pd.Series({"Rohan":20,"Ravi":20})
a
# Out:
# Rohan    20
# Ravi     20
# dtype: int64
